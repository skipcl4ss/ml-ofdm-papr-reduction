# %% [markdown]
# A test to see which number is more suitable for set_num_threads

# %%
# import torch
# import time
#
# def benchmark_threads(num_threads, matrix_size=4000, iterations=20):
#     # Set the number of threads for this test run
#     torch.set_num_threads(num_threads)
#
#     # Create two massive random matrices to simulate deep learning workloads
#     A = torch.randn(matrix_size, matrix_size)
#     B = torch.randn(matrix_size, matrix_size)
#
#     # Warmup round (gets the CPU caches loaded and ready)
#     _ = torch.matmul(A, B)
#
#     # Start the actual timer
#     start_time = time.time()
#
#     # Run the heavy math multiple times
#     for _ in range(iterations):
#         _ = torch.matmul(A, B)
#
#     end_time = time.time()
#
#     print(f"Total time with {num_threads} threads: {end_time - start_time:.4f} seconds")
#
# print("--- PyTorch CPU Thread Benchmark ---")
# # Test with 4 threads
# benchmark_threads(4)
#
# # Test with 8 threads
# benchmark_threads(8)

# %% [markdown]
# 8 threads is faster than 4 threads, so we will use 8 threads for the rest of the code

# %% [markdown]
# Cell 1: Imports and Device Setup

# %%
import numpy as np
from ofdm.metrics import calculate_papr, calculate_cm
from ofdm.plots import plot_ccdf, plot_ccdf_compare
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
# from torchmin import Minimizer
import os
import time
import matplotlib.pyplot as plt
from IPython.display import clear_output, display

# %%
# Explicitly tell PyTorch to utilize your 8 CPU cores for matrix math
# Check for GPU availability to drastically speed up training
# ! cuda is available only on nvidia gpu
torch.set_num_threads(8)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"PyTorch using {torch.get_num_threads()} threads on {device}")
# Out:
# PyTorch using 8 threads on cpu

# %%
samples_per_L = 10000

# Modulation scheme
mod = "16qam"
# mod = "qpsk"
print(f"Using {mod.upper()} modulation technique")

# clipping technique
# tech = "icf"
tech = "scf"
print(f"Using {tech} clipping technique")

# Hyperparameters
epochs = 100
# using 0.001 for Adam and 0.01 for LBFGS as default values
lr = 0.001
# lr = 0.05
lr_list = str(float(lr)).split(".")
lr_str = f"dot{lr_list[1]}" if lr < 1 else f"{lr_list[0]}dot{lr_list[1]}"
print(f"Hyperparameters: epochs = {epochs}, learning rate = {lr} ({lr_str} used in naming files), batch size = None (for now)")

# Optimizer
opt = "Adam"
# opt = "LBFGS"
print(f"Using {opt} optimizer")

# Data splitting
# ! make sure that the splitting is the same as in renormalization.ipynb
datasize = 100
# datasize = 120
train_size = 70
val_size = 10
test_size = datasize - train_size - val_size
if test_size:
    one_batch = None
else:
    test_size = 1
    one_batch = "00"
train_val_test_str = f"{train_size}_{val_size}_{test_size}" if val_size else f"{train_size}_{test_size}"
print(f"dataset of size {datasize} is split into {train_size} training files, and {val_size} validation and {test_size} testing batches respectively ({train_val_test_str} used in naming files)")

batch_suffix = ""
if one_batch:
    batch_suffix = f"Batch #{one_batch}"
    print(f"This one batch is of index {one_batch}")
    if train_size + val_size == datasize:
        print(batch_suffix, "was already used in training")

params = f"{opt} optimizer {tech.upper()} {mod.upper()} lr = {lr}\n({train_size} Training/{val_size} Validation/{test_size} Testing){" (" + batch_suffix + ")" if batch_suffix else ''}"
print(params)

pt_dir = "./testnorm/"
model_dir = "./test/"
graph_dir = "./test/"
os.makedirs(pt_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(graph_dir, exist_ok=True)
print(f'"{pt_dir}", "{model_dir}", and "{graph_dir}" are the 3 locations for pt files, nn model weights and graphs respectively')
# Out:
# Using 16QAM modulation technique
# Using scf clipping technique
# Hyperparameters: epochs = 100, learning rate = 0.001 (dot001 used in naming files), batch size = None (for now)
# Using Adam optimizer
# dataset of size 100 is split into 70 training files, and 10 validation and 20 testing batches respectively (70_10_20 used in naming files)
# Adam optimizer SCF 16QAM lr = 0.001
# (70 Training/10 Validation/20 Testing)
# "./testnorm/", "./test/", and "./test/" are the 3 locations for pt files, nn model weights and graphs respectively

# %%
def denormalize(pred_norm, minmax):
    raw_min, raw_max = minmax
    pred_raw = ((pred_norm + 1.0) / 2.0) * (raw_max - raw_min) + raw_min if raw_max != raw_min else pred_norm
    return pred_raw

# %% [markdown]
# Cell 2: Custom Activation Function

# %%
class TriangularActivation(nn.Module):
    """
    Implements the triangular activation function used in the paper's hidden layers.
    Mathematically equivalent to MATLAB's 'tribas': f(x) = max(1 - |x|, 0)
    """
    def forward(self, x):
        return torch.clamp(1.0 - torch.abs(x), min=0.0)

# %% [markdown]
# Cell 3: Highly Optimized Dataset Class

# %% [markdown]
# This is fast as it works with .pt directly without conversion

# %%
class FastOFDMDataset(Dataset):
    def __init__(self, pt_folder_path, part):
        self.folder_path = pt_folder_path
        self.part = part

    def __len__(self):
        return datasize # Assuming exactly 100 pre-computed .pt files, regardless of train/test split

    def __getitem__(self, idx):
        # Instantly loads the pre-normalized tensors directly into memory!
        file_path = os.path.join(self.folder_path, f"{mod}_{tech}_part_{idx:03d}_{self.part}.pt")
        # Load the dictionary
        data_pkg = torch.load(file_path, weights_only=False)

        # Return the tensors AND the scaling limits
        return (data_pkg['X_norm'], data_pkg['Y_norm'],
                data_pkg['X_min'], data_pkg['X_max'],
                data_pkg['Y_min'], data_pkg['Y_max'])

# %% [markdown]
# Cell 4: Neural Network Architecture

# %%
class NNSCFMapper(nn.Module):
    def __init__(self):
        super(NNSCFMapper, self).__init__()
        # First hidden layer: 2 neurons
        self.hidden1 = nn.Linear(1, 2)
        # Second hidden layer: 1 neuron
        self.hidden2 = nn.Linear(2, 1)
        # Output layer: Maps back to the original subcarrier points
        self.output = nn.Linear(1, 1)
        # Custom triangular activation
        self.activation = TriangularActivation()

    def forward(self, x):
        x = self.activation(self.hidden1(x))
        x = self.activation(self.hidden2(x))
        x = self.output(x) # Standard linear output
        return x

# %% [markdown]
# Cell 5: Initialization and DataLoaders

# %%
# todo: make edits so that it works if using one batch
# fixme: find alternative shuffling technique
# Configuration

# Initialize DataLoaders with asynchronous loading (num_workers) and rapid memory transfer
dataset_real = FastOFDMDataset(pt_dir, part='real')
if train_size < datasize:
    # ! note that the output of the Subset is saved in the original variable, may be important later
    train_dataset_real = Subset(dataset_real, range(train_size))  # Use the first train_size files for training
    val_dataset_real = Subset(dataset_real, range(train_size, train_size + val_size))

# ? should i change batch_size in the new architecture
train_loader_real = DataLoader(
    train_dataset_real,
    batch_size=None, # batch_size is None because the dataset returns a full batch of 10,000
    shuffle=True,
    # shuffle=False,
    # ! does not work locally on windows when changed to 2-4 for some reason
    num_workers=0,   # Adjust between 2-4 based on your CPU cores
    pin_memory=torch.cuda.is_available()
)

dataset_imag = FastOFDMDataset(pt_dir, part='imag')
if train_size < datasize:
    train_dataset_imag = Subset(dataset_imag, range(train_size))  # Use the first train_size files for training
    val_dataset_imag = Subset(dataset_imag, range(train_size, train_size + val_size))

train_loader_imag = DataLoader(
    train_dataset_imag,
    batch_size=None,
    shuffle=True,
    # shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)


val_loader_real = DataLoader(
    val_dataset_real,
    batch_size=None, # batch_size is None because the dataset returns a full batch of 10,000
    shuffle=False,
    # ! does not work locally on windows when changed to 2-4 for some reason
    num_workers=0,   # Adjust between 2-4 based on your CPU cores
    pin_memory=torch.cuda.is_available()
)
val_loader_imag = DataLoader(
    val_dataset_imag,
    batch_size=None,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

# Initialize models and send them to the GPU/device
Mod_Re_NN = NNSCFMapper().to(device)
Mod_Im_NN = NNSCFMapper().to(device)

# todo: see how can i use loss function to reduce ber
# Standard Mean Squared Error loss and optimizer
criterion = nn.MSELoss()
if opt == "Adam":
    optimizer_real = optim.Adam(Mod_Re_NN.parameters(), lr=lr)
    optimizer_imag = optim.Adam(Mod_Im_NN.parameters(), lr=lr)
elif opt == "LBFGS":
    optimizer_real = optim.LBFGS(Mod_Re_NN.parameters(), lr=lr, tolerance_change=1e-5, max_iter=5)
    optimizer_imag = optim.LBFGS(Mod_Im_NN.parameters(), lr=lr, tolerance_change=1e-5, max_iter=5)
# elif opt == "LM":
#     optimizer_real = Minimizer(Mod_Re_NN.parameters(), method='levenberg-marquardt')
#     optimizer_imag = Minimizer(Mod_Im_NN.parameters(), method='levenberg-marquardt')

# %% [markdown]
# Not using .compile() is actually better, it also avoids the hassle of cl.exe and needing to run "x64 Native Tools Command Prompt for VS".
#
# dont know if thats the case with gpu or not tho

# %% [markdown]
# Cell 6: Training Loop (Real Module)

# %%
print("--- Starting Training for the Real NN Module ---")
train_loss_history = []  # Track losses for graphing
val_loss_history = []
log_lines = []
total_time = 0
train_time = 0
val_time = 0

# ! if using .compile(), it is expected for the first epoch to take longer
for epoch in range(1, epochs + 1):
    start = time.time()
    epoch_train_loss = 0.0

    # Training
    Mod_Re_NN.train()
    for X_batch, Y_batch, _, _, _, _ in train_loader_real:
        # Transfer data to GPU if possible
        X_batch, Y_batch = X_batch.to(device, non_blocking=True), Y_batch.to(device, non_blocking=True)

        # MEMORYLESS RESHAPE: Flatten into a 1D column
        X_batch_flat = X_batch.view(-1, 1)
        Y_batch_flat = Y_batch.view(-1, 1)

        if opt == "Adam":
            optimizer_real.zero_grad(set_to_none=True)
            # Predict on the flattened column
            predictions = Mod_Re_NN(X_batch_flat)
            loss = criterion(predictions, Y_batch_flat)
            loss.backward()
            optimizer_real.step()
            epoch_train_loss += loss.item()
        # elif opt == "LBFGS" or opt == "LM:
        elif opt == "LBFGS":
            # L-BFGS and LM require a "closure" function to recalculate the loss, but for LM it is often required to return the unreduced residuals
            def closure():
                optimizer_real.zero_grad(set_to_none=True)
                predictions = Mod_Re_NN(X_batch_flat)

                # if opt == "LM":
                #     # LM mathematically requires the raw residuals (the difference before squaring)
                #     residuals = predictions - Y_batch_flat

                loss = criterion(predictions, Y_batch_flat)
                loss.backward()
                return loss
            # Pass the closure to the optimizer
            optimizer_real.step(closure)
            # To track the loss for your graphs, you have to call it once outside
            epoch_train_loss += closure().item()

    avg_train_loss = epoch_train_loss / len(train_loader_real)
    train_loss_history.append(avg_train_loss)  # Store loss for this epoch

    middle = time.time()

    # Validation
    Mod_Re_NN.eval()
    epoch_val_loss = 0.0
    with torch.no_grad():
        for X_val, Y_val, _, _, _, _ in val_loader_real:
            X_val, Y_val = X_val.to(device, non_blocking=True), Y_val.to(device, non_blocking=True)
            predictions = Mod_Re_NN(X_val.view(-1, 1))
            val_loss = criterion(predictions, Y_val.view(-1, 1))
            epoch_val_loss += val_loss.item()

    avg_val_loss = epoch_val_loss / len(val_loader_real)
    val_loss_history.append(avg_val_loss)

    end = time.time()

    train_time += middle - start
    val_time += end - middle
    total_time += end - start
    line = f'Real Module | Epoch {epoch}/{epochs} | Train Loss: {avg_train_loss:.6f} | Val Loss {avg_val_loss:.6f} | Time: {end - start:.2f} seconds'
    log_lines.append(line)

    if epoch % 5 == 0 or epoch == epochs:
        clear_output(wait=True)
        plt.figure(figsize=(10, 7))
        plt.plot(range(1, len(train_loss_history) + 1), train_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Train Loss")
        plt.plot(range(1, len(val_loss_history) + 1), val_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Validation Loss")
        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel('Loss (MSE)', fontsize=12)
        plt.legend()
        plt.title(f'Real Module Training & Validation Loss over Epochs\n{params}', fontsize=14, fontweight='bold')
        plt.xlim(0, epochs + 1)
        margin = (max(train_loss_history) - min(train_loss_history)) * 0.1 if len(train_loss_history) > 1 else 0.1
        plt.ylim(min(train_loss_history) - margin, max(train_loss_history) + margin)
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()
        print(*log_lines, sep='\n')
    else:
        print(line)


print(f'Real NN Module Training Complete in {int(total_time // 3600)}:{int(total_time // 60)}:{total_time % 60:.1f} hours! ({int(train_time // 3600)}:{int(train_time // 60)}:{train_time % 60:.1f} hours in training and {int(val_time // 3600)}:{int(val_time // 60)}:{val_time % 60:.1f} hours in validation)')

# Plot loss vs epoch
plt.figure(figsize=(10, 7))
plt.plot(range(1, epochs + 1), train_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Training Loss")
plt.plot(range(1, epochs + 1), val_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Validation Loss")
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss (MSE)', fontsize=12)
plt.legend()
plt.title(f'Real Module Training & Validation Loss over Epochs\n{params}', fontsize=14, fontweight='bold')
plt.xlim(0, epochs + 1)
margin = (max(train_loss_history) - min(train_loss_history)) * 0.1
plt.ylim(min(train_loss_history) - margin, max(train_loss_history) + margin)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(graph_dir, f"{opt}_{mod}_{tech}_real_loss_{train_val_test_str}_{lr_str}.png"), dpi=150)
plt.show()
# Out:
# Real Module | Epoch 1/100 | Train Loss: 1.123539 | Val Loss 0.892790 | Time: 29.98 seconds
# Real Module | Epoch 2/100 | Train Loss: 0.728864 | Val Loss 0.586054 | Time: 29.15 seconds
# Real Module | Epoch 3/100 | Train Loss: 0.485960 | Val Loss 0.398032 | Time: 37.13 seconds
# Real Module | Epoch 4/100 | Train Loss: 0.335253 | Val Loss 0.279622 | Time: 36.47 seconds
# Real Module | Epoch 5/100 | Train Loss: 0.239379 | Val Loss 0.203599 | Time: 35.21 seconds
# Real Module | Epoch 6/100 | Train Loss: 0.179374 | Val Loss 0.162266 | Time: 33.70 seconds
# Real Module | Epoch 7/100 | Train Loss: 0.153553 | Val Loss 0.145603 | Time: 33.38 seconds
# Real Module | Epoch 8/100 | Train Loss: 0.138943 | Val Loss 0.132532 | Time: 33.39 seconds
# Real Module | Epoch 9/100 | Train Loss: 0.126943 | Val Loss 0.121528 | Time: 33.19 seconds
# Real Module | Epoch 10/100 | Train Loss: 0.116741 | Val Loss 0.112091 | Time: 33.47 seconds
# Real Module | Epoch 11/100 | Train Loss: 0.107954 | Val Loss 0.103931 | Time: 33.50 seconds
# Real Module | Epoch 12/100 | Train Loss: 0.100314 | Val Loss 0.096778 | Time: 34.01 seconds
# Real Module | Epoch 13/100 | Train Loss: 0.093554 | Val Loss 0.090387 | Time: 33.76 seconds
# Real Module | Epoch 14/100 | Train Loss: 0.087458 | Val Loss 0.084564 | Time: 34.08 seconds
# Real Module | Epoch 15/100 | Train Loss: 0.081853 | Val Loss 0.079161 | Time: 34.08 seconds
# Real Module | Epoch 16/100 | Train Loss: 0.076612 | Val Loss 0.074069 | Time: 33.81 seconds
# Real Module | Epoch 17/100 | Train Loss: 0.071637 | Val Loss 0.069200 | Time: 33.54 seconds
# Real Module | Epoch 18/100 | Train Loss: 0.066853 | Val Loss 0.064494 | Time: 34.54 seconds
# Real Module | Epoch 19/100 | Train Loss: 0.062211 | Val Loss 0.059910 | Time: 33.51 seconds
# Real Module | Epoch 20/100 | Train Loss: 0.057680 | Val Loss 0.055427 | Time: 32.81 seconds
# Real Module | Epoch 21/100 | Train Loss: 0.053244 | Val Loss 0.051038 | Time: 32.80 seconds
# Real Module | Epoch 22/100 | Train Loss: 0.048904 | Val Loss 0.046747 | Time: 32.83 seconds
# Real Module | Epoch 23/100 | Train Loss: 0.044673 | Val Loss 0.042581 | Time: 33.28 seconds
# Real Module | Epoch 24/100 | Train Loss: 0.040591 | Val Loss 0.038594 | Time: 32.82 seconds
# Real Module | Epoch 25/100 | Train Loss: 0.036723 | Val Loss 0.034860 | Time: 32.58 seconds
# Real Module | Epoch 26/100 | Train Loss: 0.033145 | Val Loss 0.031450 | Time: 32.81 seconds
# Real Module | Epoch 27/100 | Train Loss: 0.029914 | Val Loss 0.028406 | Time: 32.41 seconds
# Real Module | Epoch 28/100 | Train Loss: 0.027052 | Val Loss 0.025728 | Time: 32.57 seconds
# Real Module | Epoch 29/100 | Train Loss: 0.024544 | Val Loss 0.023390 | Time: 32.52 seconds
# Real Module | Epoch 30/100 | Train Loss: 0.022358 | Val Loss 0.021351 | Time: 32.53 seconds
# Real Module | Epoch 31/100 | Train Loss: 0.020446 | Val Loss 0.019562 | Time: 33.31 seconds
# Real Module | Epoch 32/100 | Train Loss: 0.018759 | Val Loss 0.017971 | Time: 34.13 seconds
# Real Module | Epoch 33/100 | Train Loss: 0.017248 | Val Loss 0.016535 | Time: 32.57 seconds
# Real Module | Epoch 34/100 | Train Loss: 0.015870 | Val Loss 0.015211 | Time: 32.64 seconds
# Real Module | Epoch 35/100 | Train Loss: 0.014586 | Val Loss 0.013960 | Time: 32.56 seconds
# Real Module | Epoch 36/100 | Train Loss: 0.013361 | Val Loss 0.012759 | Time: 32.36 seconds
# Real Module | Epoch 37/100 | Train Loss: 0.012204 | Val Loss 0.011674 | Time: 32.25 seconds
# Real Module | Epoch 38/100 | Train Loss: 0.011215 | Val Loss 0.010777 | Time: 32.04 seconds
# Real Module | Epoch 39/100 | Train Loss: 0.010393 | Val Loss 0.010025 | Time: 32.37 seconds
# Real Module | Epoch 40/100 | Train Loss: 0.009696 | Val Loss 0.009378 | Time: 32.00 seconds
# Real Module | Epoch 41/100 | Train Loss: 0.009090 | Val Loss 0.008811 | Time: 32.46 seconds
# Real Module | Epoch 42/100 | Train Loss: 0.008556 | Val Loss 0.008308 | Time: 32.27 seconds
# Real Module | Epoch 43/100 | Train Loss: 0.008079 | Val Loss 0.007857 | Time: 32.53 seconds
# Real Module | Epoch 44/100 | Train Loss: 0.007650 | Val Loss 0.007448 | Time: 32.34 seconds
# Real Module | Epoch 45/100 | Train Loss: 0.007259 | Val Loss 0.007074 | Time: 32.30 seconds
# Real Module | Epoch 46/100 | Train Loss: 0.006900 | Val Loss 0.006729 | Time: 32.33 seconds
# Real Module | Epoch 47/100 | Train Loss: 0.006566 | Val Loss 0.006406 | Time: 32.24 seconds
# Real Module | Epoch 48/100 | Train Loss: 0.006253 | Val Loss 0.006104 | Time: 32.04 seconds
# Real Module | Epoch 49/100 | Train Loss: 0.005960 | Val Loss 0.005820 | Time: 32.13 seconds
# Real Module | Epoch 50/100 | Train Loss: 0.005684 | Val Loss 0.005550 | Time: 32.51 seconds
# Real Module | Epoch 51/100 | Train Loss: 0.005421 | Val Loss 0.005294 | Time: 32.15 seconds
# Real Module | Epoch 52/100 | Train Loss: 0.005170 | Val Loss 0.005049 | Time: 32.44 seconds
# Real Module | Epoch 53/100 | Train Loss: 0.004931 | Val Loss 0.004815 | Time: 32.28 seconds
# Real Module | Epoch 54/100 | Train Loss: 0.004702 | Val Loss 0.004591 | Time: 32.62 seconds
# Real Module | Epoch 55/100 | Train Loss: 0.004482 | Val Loss 0.004376 | Time: 32.19 seconds
# Real Module | Epoch 56/100 | Train Loss: 0.004272 | Val Loss 0.004169 | Time: 32.21 seconds
# Real Module | Epoch 57/100 | Train Loss: 0.004070 | Val Loss 0.003972 | Time: 32.12 seconds
# Real Module | Epoch 58/100 | Train Loss: 0.003876 | Val Loss 0.003782 | Time: 32.05 seconds
# Real Module | Epoch 59/100 | Train Loss: 0.003691 | Val Loss 0.003601 | Time: 32.06 seconds
# Real Module | Epoch 60/100 | Train Loss: 0.003514 | Val Loss 0.003428 | Time: 32.24 seconds
# Real Module | Epoch 61/100 | Train Loss: 0.003344 | Val Loss 0.003262 | Time: 32.09 seconds
# Real Module | Epoch 62/100 | Train Loss: 0.003182 | Val Loss 0.003104 | Time: 32.21 seconds
# Real Module | Epoch 63/100 | Train Loss: 0.003028 | Val Loss 0.002953 | Time: 31.75 seconds
# Real Module | Epoch 64/100 | Train Loss: 0.002880 | Val Loss 0.002809 | Time: 31.99 seconds
# Real Module | Epoch 65/100 | Train Loss: 0.002740 | Val Loss 0.002672 | Time: 32.31 seconds
# Real Module | Epoch 66/100 | Train Loss: 0.002606 | Val Loss 0.002541 | Time: 32.43 seconds
# Real Module | Epoch 67/100 | Train Loss: 0.002478 | Val Loss 0.002416 | Time: 32.05 seconds
# Real Module | Epoch 68/100 | Train Loss: 0.002356 | Val Loss 0.002298 | Time: 32.20 seconds
# Real Module | Epoch 69/100 | Train Loss: 0.002241 | Val Loss 0.002185 | Time: 32.22 seconds
# Real Module | Epoch 70/100 | Train Loss: 0.002131 | Val Loss 0.002078 | Time: 31.94 seconds
# Real Module | Epoch 71/100 | Train Loss: 0.002026 | Val Loss 0.001976 | Time: 32.06 seconds
# Real Module | Epoch 72/100 | Train Loss: 0.001927 | Val Loss 0.001879 | Time: 32.28 seconds
# Real Module | Epoch 73/100 | Train Loss: 0.001833 | Val Loss 0.001787 | Time: 32.93 seconds
# Real Module | Epoch 74/100 | Train Loss: 0.001743 | Val Loss 0.001700 | Time: 31.97 seconds
# Real Module | Epoch 75/100 | Train Loss: 0.001658 | Val Loss 0.001617 | Time: 32.19 seconds
# Real Module | Epoch 76/100 | Train Loss: 0.001578 | Val Loss 0.001539 | Time: 32.55 seconds
# Real Module | Epoch 77/100 | Train Loss: 0.001501 | Val Loss 0.001464 | Time: 32.17 seconds
# Real Module | Epoch 78/100 | Train Loss: 0.001429 | Val Loss 0.001393 | Time: 32.15 seconds
# Real Module | Epoch 79/100 | Train Loss: 0.001360 | Val Loss 0.001326 | Time: 31.81 seconds
# Real Module | Epoch 80/100 | Train Loss: 0.001294 | Val Loss 0.001263 | Time: 32.25 seconds
# Real Module | Epoch 81/100 | Train Loss: 0.001232 | Val Loss 0.001202 | Time: 31.71 seconds
# Real Module | Epoch 82/100 | Train Loss: 0.001174 | Val Loss 0.001145 | Time: 32.20 seconds
# Real Module | Epoch 83/100 | Train Loss: 0.001118 | Val Loss 0.001091 | Time: 31.95 seconds
# Real Module | Epoch 84/100 | Train Loss: 0.001065 | Val Loss 0.001040 | Time: 31.74 seconds
# Real Module | Epoch 85/100 | Train Loss: 0.001015 | Val Loss 0.000991 | Time: 32.03 seconds
# Real Module | Epoch 86/100 | Train Loss: 0.000968 | Val Loss 0.000945 | Time: 32.26 seconds
# Real Module | Epoch 87/100 | Train Loss: 0.000923 | Val Loss 0.000902 | Time: 31.80 seconds
# Real Module | Epoch 88/100 | Train Loss: 0.000881 | Val Loss 0.000861 | Time: 32.13 seconds
# Real Module | Epoch 89/100 | Train Loss: 0.000841 | Val Loss 0.000822 | Time: 32.32 seconds
# Real Module | Epoch 90/100 | Train Loss: 0.000803 | Val Loss 0.000785 | Time: 32.16 seconds
# Real Module | Epoch 91/100 | Train Loss: 0.000767 | Val Loss 0.000750 | Time: 32.72 seconds
# Real Module | Epoch 92/100 | Train Loss: 0.000733 | Val Loss 0.000717 | Time: 35.66 seconds
# Real Module | Epoch 93/100 | Train Loss: 0.000701 | Val Loss 0.000686 | Time: 33.29 seconds
# Real Module | Epoch 94/100 | Train Loss: 0.000671 | Val Loss 0.000656 | Time: 32.63 seconds
# Real Module | Epoch 95/100 | Train Loss: 0.000643 | Val Loss 0.000629 | Time: 32.86 seconds
# Real Module | Epoch 96/100 | Train Loss: 0.000615 | Val Loss 0.000602 | Time: 32.95 seconds
# Real Module | Epoch 97/100 | Train Loss: 0.000590 | Val Loss 0.000577 | Time: 33.03 seconds
# Real Module | Epoch 98/100 | Train Loss: 0.000566 | Val Loss 0.000554 | Time: 33.39 seconds
# Real Module | Epoch 99/100 | Train Loss: 0.000543 | Val Loss 0.000532 | Time: 33.89 seconds
# Real Module | Epoch 100/100 | Train Loss: 0.000522 | Val Loss 0.000511 | Time: 33.14 seconds
# Real NN Module Training Complete in 0:54:29.0 hours! (0:50:44.0 hours in training and 0:3:45.0 hours in validation)

# %% [markdown]
# Cell 7: Training Loop (Imaginary Module)

# %%
print("--- Starting Training for the Imaginary NN Module ---")
train_loss_history = []  # Track losses for graphing
val_loss_history = []
log_lines = []
total_time = 0
train_time = 0
val_time = 0

for epoch in range(1, epochs + 1):
    start = time.time()

    # Training
    Mod_Im_NN.train()
    epoch_train_loss = 0.0
    for X_batch, Y_batch, _, _, _, _ in train_loader_imag:
        # Transfer data to GPU if possible
        X_batch, Y_batch = X_batch.to(device, non_blocking=True), Y_batch.to(device, non_blocking=True)

        # MEMORYLESS RESHAPE: Flatten into a 1D column
        X_batch_flat = X_batch.view(-1, 1)
        Y_batch_flat = Y_batch.view(-1, 1)

        if opt == "Adam":
            optimizer_imag.zero_grad(set_to_none=True)
            # Predict on the flattened column
            predictions = Mod_Im_NN(X_batch_flat)
            loss = criterion(predictions, Y_batch_flat)
            loss.backward()
            optimizer_imag.step()
            epoch_train_loss += loss.item()
        # elif opt == "LBFGS" or opt == "LM:
        elif opt == "LBFGS":
            # L-BFGS and LM require a "closure" function to recalculate the loss, but for LM it is often required to return the unreduced residuals
            def closure():
                optimizer_imag.zero_grad(set_to_none=True)
                predictions = Mod_Im_NN(X_batch_flat)

                # if opt == "LM":
                #     # LM mathematically requires the raw residuals (the difference before squaring)
                #     residuals = predictions - Y_batch_flat

                loss = criterion(predictions, Y_batch_flat)
                loss.backward()
                return loss
            # Pass the closure to the optimizer
            optimizer_imag.step(closure)
            # To track the loss for your graphs, you have to call it once outside
            epoch_train_loss += closure().item()

    avg_train_loss = epoch_train_loss / len(train_loader_imag)
    train_loss_history.append(avg_train_loss)  # Store loss for this epoch

    middle = time.time()

    # Validation
    Mod_Im_NN.eval()
    epoch_val_loss = 0.0
    with torch.no_grad():
        for X_val, Y_val, _, _, _, _ in val_loader_imag:
            X_val, Y_val = X_val.to(device, non_blocking=True), Y_val.to(device, non_blocking=True)
            predictions = Mod_Im_NN(X_val.view(-1, 1))
            val_loss = criterion(predictions, Y_val.view(-1, 1))
            epoch_val_loss += val_loss.item()

    avg_val_loss = epoch_val_loss / len(val_loader_imag)
    val_loss_history.append(avg_val_loss)

    end = time.time()

    train_time += middle - start
    val_time += end - middle
    total_time += end - start
    line = f'Imaginary Module | Epoch {epoch}/{epochs} | Train Loss: {avg_train_loss:.6f} | Val Loss {avg_val_loss:.6f} | Time: {end - start:.2f} seconds'
    log_lines.append(line)

    if epoch % 5 == 0 or epoch == epochs:
        clear_output(wait=True)
        plt.figure(figsize=(10, 7))
        plt.plot(range(1, len(train_loss_history) + 1), train_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Train Loss")
        plt.plot(range(1, len(val_loss_history) + 1), val_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Validation Loss")
        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel('Loss (MSE)', fontsize=12)
        plt.legend()
        plt.title(f'Imaginary Module Training & Validation Loss over Epochs\n{params}', fontsize=14, fontweight='bold')
        plt.xlim(0, epochs + 1)
        margin = (max(train_loss_history) - min(train_loss_history)) * 0.1 if len(train_loss_history) > 1 else 0.1
        plt.ylim(min(train_loss_history) - margin, max(train_loss_history) + margin)
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()
        print(*log_lines, sep='\n')
    else:
        print(line)


print(f'Imaginary NN Module Training Complete in {int(total_time // 3600)}:{int(total_time // 60)}:{total_time % 60:.1f} hours! ({int(train_time // 3600)}:{int(train_time // 60)}:{train_time % 60:.1f} hours in training and {int(val_time // 3600)}:{int(val_time // 60)}:{val_time % 60:.1f} hours in validation)')

# Plot loss vs epoch
plt.figure(figsize=(10, 7))
plt.plot(range(1, epochs + 1), train_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Training Loss")
plt.plot(range(1, epochs + 1), val_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Validation Loss")
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss (MSE)', fontsize=12)
plt.legend()
plt.title(f'Imaginary Module Training & Validation Loss over Epochs\n{params}', fontsize=14, fontweight='bold')
plt.xlim(0, epochs + 1)
margin = (max(train_loss_history) - min(train_loss_history)) * 0.1
plt.ylim(min(train_loss_history) - margin, max(train_loss_history) + margin)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(graph_dir, f"{opt}_{mod}_{tech}_imag_loss_{train_val_test_str}_{lr_str}.png"), dpi=150)
plt.show()
# Out:
# Imaginary Module | Epoch 1/100 | Train Loss: 0.317284 | Val Loss 0.225875 | Time: 34.38 seconds
# Imaginary Module | Epoch 2/100 | Train Loss: 0.175947 | Val Loss 0.137635 | Time: 33.65 seconds
# Imaginary Module | Epoch 3/100 | Train Loss: 0.117532 | Val Loss 0.102277 | Time: 34.64 seconds
# Imaginary Module | Epoch 4/100 | Train Loss: 0.094182 | Val Loss 0.087783 | Time: 33.43 seconds
# Imaginary Module | Epoch 5/100 | Train Loss: 0.083782 | Val Loss 0.080227 | Time: 33.40 seconds
# Imaginary Module | Epoch 6/100 | Train Loss: 0.077370 | Val Loss 0.074553 | Time: 33.37 seconds
# Imaginary Module | Epoch 7/100 | Train Loss: 0.071921 | Val Loss 0.069207 | Time: 33.07 seconds
# Imaginary Module | Epoch 8/100 | Train Loss: 0.066520 | Val Loss 0.063702 | Time: 32.32 seconds
# Imaginary Module | Epoch 9/100 | Train Loss: 0.060841 | Val Loss 0.057819 | Time: 32.91 seconds
# Imaginary Module | Epoch 10/100 | Train Loss: 0.054711 | Val Loss 0.051420 | Time: 33.23 seconds
# Imaginary Module | Epoch 11/100 | Train Loss: 0.048064 | Val Loss 0.044642 | Time: 33.60 seconds
# Imaginary Module | Epoch 12/100 | Train Loss: 0.041630 | Val Loss 0.038662 | Time: 33.55 seconds
# Imaginary Module | Epoch 13/100 | Train Loss: 0.035977 | Val Loss 0.033301 | Time: 34.76 seconds
# Imaginary Module | Epoch 14/100 | Train Loss: 0.030869 | Val Loss 0.028455 | Time: 33.31 seconds
# Imaginary Module | Epoch 15/100 | Train Loss: 0.026296 | Val Loss 0.024173 | Time: 33.37 seconds
# Imaginary Module | Epoch 16/100 | Train Loss: 0.022319 | Val Loss 0.020517 | Time: 32.98 seconds
# Imaginary Module | Epoch 17/100 | Train Loss: 0.018976 | Val Loss 0.017493 | Time: 34.20 seconds
# Imaginary Module | Epoch 18/100 | Train Loss: 0.016250 | Val Loss 0.015063 | Time: 34.08 seconds
# Imaginary Module | Epoch 19/100 | Train Loss: 0.014079 | Val Loss 0.013142 | Time: 33.46 seconds
# Imaginary Module | Epoch 20/100 | Train Loss: 0.012371 | Val Loss 0.011639 | Time: 33.16 seconds
# Imaginary Module | Epoch 21/100 | Train Loss: 0.011035 | Val Loss 0.010457 | Time: 32.70 seconds
# Imaginary Module | Epoch 22/100 | Train Loss: 0.009972 | Val Loss 0.009503 | Time: 32.89 seconds
# Imaginary Module | Epoch 23/100 | Train Loss: 0.009103 | Val Loss 0.008716 | Time: 32.97 seconds
# Imaginary Module | Epoch 24/100 | Train Loss: 0.008380 | Val Loss 0.008050 | Time: 33.33 seconds
# Imaginary Module | Epoch 25/100 | Train Loss: 0.007756 | Val Loss 0.007464 | Time: 33.07 seconds
# Imaginary Module | Epoch 26/100 | Train Loss: 0.007197 | Val Loss 0.006930 | Time: 33.38 seconds
# Imaginary Module | Epoch 27/100 | Train Loss: 0.006680 | Val Loss 0.006428 | Time: 33.34 seconds
# Imaginary Module | Epoch 28/100 | Train Loss: 0.006189 | Val Loss 0.005946 | Time: 33.25 seconds
# Imaginary Module | Epoch 29/100 | Train Loss: 0.005714 | Val Loss 0.005478 | Time: 33.13 seconds
# Imaginary Module | Epoch 30/100 | Train Loss: 0.005253 | Val Loss 0.005025 | Time: 32.57 seconds
# Imaginary Module | Epoch 31/100 | Train Loss: 0.004809 | Val Loss 0.004592 | Time: 32.68 seconds
# Imaginary Module | Epoch 32/100 | Train Loss: 0.004389 | Val Loss 0.004189 | Time: 32.51 seconds
# Imaginary Module | Epoch 33/100 | Train Loss: 0.004006 | Val Loss 0.003832 | Time: 32.82 seconds
# Imaginary Module | Epoch 34/100 | Train Loss: 0.003683 | Val Loss 0.003544 | Time: 32.97 seconds
# Imaginary Module | Epoch 35/100 | Train Loss: 0.003425 | Val Loss 0.003311 | Time: 32.85 seconds
# Imaginary Module | Epoch 36/100 | Train Loss: 0.003210 | Val Loss 0.003113 | Time: 32.04 seconds
# Imaginary Module | Epoch 37/100 | Train Loss: 0.003023 | Val Loss 0.002937 | Time: 32.53 seconds
# Imaginary Module | Epoch 38/100 | Train Loss: 0.002857 | Val Loss 0.002779 | Time: 32.47 seconds
# Imaginary Module | Epoch 39/100 | Train Loss: 0.002706 | Val Loss 0.002634 | Time: 32.55 seconds
# Imaginary Module | Epoch 40/100 | Train Loss: 0.002566 | Val Loss 0.002500 | Time: 32.84 seconds
# Imaginary Module | Epoch 41/100 | Train Loss: 0.002437 | Val Loss 0.002375 | Time: 33.33 seconds
# Imaginary Module | Epoch 42/100 | Train Loss: 0.002315 | Val Loss 0.002258 | Time: 33.00 seconds
# Imaginary Module | Epoch 43/100 | Train Loss: 0.002201 | Val Loss 0.002147 | Time: 33.00 seconds
# Imaginary Module | Epoch 44/100 | Train Loss: 0.002094 | Val Loss 0.002042 | Time: 33.14 seconds
# Imaginary Module | Epoch 45/100 | Train Loss: 0.001992 | Val Loss 0.001943 | Time: 33.47 seconds
# Imaginary Module | Epoch 46/100 | Train Loss: 0.001895 | Val Loss 0.001849 | Time: 33.14 seconds
# Imaginary Module | Epoch 47/100 | Train Loss: 0.001803 | Val Loss 0.001759 | Time: 32.57 seconds
# Imaginary Module | Epoch 48/100 | Train Loss: 0.001716 | Val Loss 0.001674 | Time: 34.77 seconds
# Imaginary Module | Epoch 49/100 | Train Loss: 0.001633 | Val Loss 0.001593 | Time: 35.26 seconds
# Imaginary Module | Epoch 50/100 | Train Loss: 0.001554 | Val Loss 0.001516 | Time: 31.25 seconds
# Imaginary Module | Epoch 51/100 | Train Loss: 0.001479 | Val Loss 0.001443 | Time: 29.93 seconds
# Imaginary Module | Epoch 52/100 | Train Loss: 0.001408 | Val Loss 0.001374 | Time: 32.14 seconds
# Imaginary Module | Epoch 53/100 | Train Loss: 0.001340 | Val Loss 0.001308 | Time: 31.33 seconds
# Imaginary Module | Epoch 54/100 | Train Loss: 0.001276 | Val Loss 0.001246 | Time: 31.36 seconds
# Imaginary Module | Epoch 55/100 | Train Loss: 0.001215 | Val Loss 0.001186 | Time: 31.09 seconds
# Imaginary Module | Epoch 56/100 | Train Loss: 0.001158 | Val Loss 0.001130 | Time: 37.63 seconds
# Imaginary Module | Epoch 57/100 | Train Loss: 0.001103 | Val Loss 0.001077 | Time: 33.11 seconds
# Imaginary Module | Epoch 58/100 | Train Loss: 0.001051 | Val Loss 0.001026 | Time: 33.37 seconds
# Imaginary Module | Epoch 59/100 | Train Loss: 0.001002 | Val Loss 0.000979 | Time: 33.86 seconds
# Imaginary Module | Epoch 60/100 | Train Loss: 0.000955 | Val Loss 0.000933 | Time: 34.01 seconds
# Imaginary Module | Epoch 61/100 | Train Loss: 0.000911 | Val Loss 0.000890 | Time: 33.27 seconds
# Imaginary Module | Epoch 62/100 | Train Loss: 0.000869 | Val Loss 0.000850 | Time: 33.41 seconds
# Imaginary Module | Epoch 63/100 | Train Loss: 0.000830 | Val Loss 0.000811 | Time: 32.76 seconds
# Imaginary Module | Epoch 64/100 | Train Loss: 0.000793 | Val Loss 0.000775 | Time: 31.52 seconds
# Imaginary Module | Epoch 65/100 | Train Loss: 0.000757 | Val Loss 0.000741 | Time: 29.69 seconds
# Imaginary Module | Epoch 66/100 | Train Loss: 0.000724 | Val Loss 0.000708 | Time: 29.86 seconds
# Imaginary Module | Epoch 67/100 | Train Loss: 0.000692 | Val Loss 0.000677 | Time: 30.03 seconds
# Imaginary Module | Epoch 68/100 | Train Loss: 0.000662 | Val Loss 0.000648 | Time: 29.59 seconds
# Imaginary Module | Epoch 69/100 | Train Loss: 0.000634 | Val Loss 0.000621 | Time: 29.98 seconds
# Imaginary Module | Epoch 70/100 | Train Loss: 0.000608 | Val Loss 0.000595 | Time: 29.59 seconds
# Imaginary Module | Epoch 71/100 | Train Loss: 0.000583 | Val Loss 0.000571 | Time: 29.29 seconds
# Imaginary Module | Epoch 72/100 | Train Loss: 0.000559 | Val Loss 0.000548 | Time: 29.78 seconds
# Imaginary Module | Epoch 73/100 | Train Loss: 0.000536 | Val Loss 0.000526 | Time: 29.64 seconds
# Imaginary Module | Epoch 74/100 | Train Loss: 0.000515 | Val Loss 0.000505 | Time: 32.10 seconds
# Imaginary Module | Epoch 75/100 | Train Loss: 0.000495 | Val Loss 0.000486 | Time: 32.95 seconds
# Imaginary Module | Epoch 76/100 | Train Loss: 0.000476 | Val Loss 0.000468 | Time: 32.45 seconds
# Imaginary Module | Epoch 77/100 | Train Loss: 0.000459 | Val Loss 0.000450 | Time: 32.42 seconds
# Imaginary Module | Epoch 78/100 | Train Loss: 0.000442 | Val Loss 0.000434 | Time: 32.48 seconds
# Imaginary Module | Epoch 79/100 | Train Loss: 0.000426 | Val Loss 0.000419 | Time: 32.39 seconds
# Imaginary Module | Epoch 80/100 | Train Loss: 0.000411 | Val Loss 0.000404 | Time: 32.56 seconds
# Imaginary Module | Epoch 81/100 | Train Loss: 0.000397 | Val Loss 0.000390 | Time: 32.46 seconds
# Imaginary Module | Epoch 82/100 | Train Loss: 0.000384 | Val Loss 0.000378 | Time: 32.03 seconds
# Imaginary Module | Epoch 83/100 | Train Loss: 0.000371 | Val Loss 0.000365 | Time: 32.32 seconds
# Imaginary Module | Epoch 84/100 | Train Loss: 0.000360 | Val Loss 0.000354 | Time: 32.17 seconds
# Imaginary Module | Epoch 85/100 | Train Loss: 0.000348 | Val Loss 0.000343 | Time: 32.44 seconds
# Imaginary Module | Epoch 86/100 | Train Loss: 0.000338 | Val Loss 0.000333 | Time: 32.34 seconds
# Imaginary Module | Epoch 87/100 | Train Loss: 0.000328 | Val Loss 0.000324 | Time: 32.59 seconds
# Imaginary Module | Epoch 88/100 | Train Loss: 0.000319 | Val Loss 0.000315 | Time: 32.54 seconds
# Imaginary Module | Epoch 89/100 | Train Loss: 0.000310 | Val Loss 0.000306 | Time: 32.17 seconds
# Imaginary Module | Epoch 90/100 | Train Loss: 0.000302 | Val Loss 0.000298 | Time: 32.34 seconds
# Imaginary Module | Epoch 91/100 | Train Loss: 0.000294 | Val Loss 0.000291 | Time: 32.51 seconds
# Imaginary Module | Epoch 92/100 | Train Loss: 0.000287 | Val Loss 0.000284 | Time: 32.54 seconds
# Imaginary Module | Epoch 93/100 | Train Loss: 0.000281 | Val Loss 0.000277 | Time: 32.89 seconds
# Imaginary Module | Epoch 94/100 | Train Loss: 0.000274 | Val Loss 0.000271 | Time: 32.28 seconds
# Imaginary Module | Epoch 95/100 | Train Loss: 0.000268 | Val Loss 0.000265 | Time: 32.32 seconds
# Imaginary Module | Epoch 96/100 | Train Loss: 0.000263 | Val Loss 0.000260 | Time: 32.63 seconds
# Imaginary Module | Epoch 97/100 | Train Loss: 0.000258 | Val Loss 0.000255 | Time: 32.45 seconds
# Imaginary Module | Epoch 98/100 | Train Loss: 0.000253 | Val Loss 0.000250 | Time: 32.21 seconds
# Imaginary Module | Epoch 99/100 | Train Loss: 0.000248 | Val Loss 0.000246 | Time: 31.93 seconds
# Imaginary Module | Epoch 100/100 | Train Loss: 0.000244 | Val Loss 0.000242 | Time: 32.20 seconds
# Imaginary NN Module Training Complete in 0:54:21.6 hours! (0:50:38.3 hours in training and 0:3:43.3 hours in validation)

# %% [markdown]
# Cell 8: Saving the Models

# %%
# Save the trained models
torch.save(Mod_Re_NN.state_dict(), os.path.join(model_dir, f"{opt}_{mod}_{tech}_mod_re_weights_{train_val_test_str}_{lr_str}.pth"))
torch.save(Mod_Im_NN.state_dict(), os.path.join(model_dir, f"{opt}_{mod}_{tech}_mod_im_weights_{train_val_test_str}_{lr_str}.pth"))
print("\nTraining complete and weights saved!")
# Out:
# Training complete and weights saved!

# %% [markdown]
# Since we already saved the models, we can comment out most of the previous code blocks

# %% [markdown]
# Cell 9: Testing

# %%
# 1. Load the Saved Models
Test_Mod_Re = NNSCFMapper().to(device)
Test_Mod_Im = NNSCFMapper().to(device)

Test_Mod_Re.load_state_dict(torch.load(os.path.join(model_dir, f"{opt}_{mod}_{tech}_mod_re_weights_{train_val_test_str}_{lr_str}.pth"), weights_only=True))
Test_Mod_Im.load_state_dict(torch.load(os.path.join(model_dir, f"{opt}_{mod}_{tech}_mod_im_weights_{train_val_test_str}_{lr_str}.pth"), weights_only=True))

Test_Mod_Re.eval()
Test_Mod_Im.eval()
# Out:
# NNSCFMapper(
#   (hidden1): Linear(in_features=1, out_features=2, bias=True)
#   (hidden2): Linear(in_features=2, out_features=1, bias=True)
#   (output): Linear(in_features=1, out_features=1, bias=True)
#   (activation): TriangularActivation()
# )

# %%
if one_batch:
    # 2. Grab one batch of data to test (Load the dictionary packages)
    pkg_real = torch.load(os.path.join(pt_dir, f"{mod}_{tech}_part_{one_batch}_real.pt"), weights_only=False)
    pkg_imag = torch.load(os.path.join(pt_dir, f"{mod}_{tech}_part_{one_batch}_imag.pt"), weights_only=False)
    # Extract tensors
    test_X_real, test_Y_real = pkg_real['X_norm'], pkg_real['Y_norm']
    test_X_imag, test_Y_imag = pkg_imag['X_norm'], pkg_imag['Y_norm']

    # 3. Generate Predictions (Reshape, Predict, Reshape back)
    with torch.no_grad():
        # Memoryless flattening
        X_real_flat = test_X_real.view(-1, 1).to(device)
        X_imag_flat = test_X_imag.view(-1, 1).to(device)

        predicted_real = Test_Mod_Re(X_real_flat).view_as(test_X_real).cpu().numpy()
        predicted_imag = Test_Mod_Im(X_imag_flat).view_as(test_X_imag).cpu().numpy()

    # Denormalize using exact dictionary limits
    pred_denorm_real = denormalize(predicted_real, (pkg_real['X_min'], pkg_real['X_max']))
    pred_denorm_imag = denormalize(predicted_imag, (pkg_imag['X_min'], pkg_imag['X_max']))

    # 4. Reconstruct the Complex OFDM Signals
    original_complex = test_X_real.numpy() + 1j * test_X_imag.numpy()
    clipped_complex = test_Y_real.numpy() + 1j * test_Y_imag.numpy()
    predicted_complex = pred_denorm_real + 1j * pred_denorm_imag
else:
#     # 2. Setup the Test Data (Files train_size->99)
#     test_dataset_real = Subset(FastOFDMDataset(pt_dir, part='real'), range(train_size, datasize))
#     test_dataset_imag = Subset(FastOFDMDataset(pt_dir, part='imag'), range(train_size, datasize))
    # 2. Setup the Test Data (Files (train_size+val_size)->99)
    test_dataset_real = Subset(dataset_real, range(train_size + val_size, datasize))
    test_dataset_imag = Subset(dataset_imag, range(train_size + val_size, datasize))

    # We set shuffle=False to ensure real and imag batches stay perfectly aligned
    test_loader_real = DataLoader(test_dataset_real, batch_size=None, shuffle=False)
    test_loader_imag = DataLoader(test_dataset_imag, batch_size=None, shuffle=False)

    # 3. Generate Predictions for all test_size test files
    all_original, all_clipped, all_predicted = [], [], []

    test_loss_real = 0.0
    test_loss_imag = 0.0
    with torch.no_grad():
        for (X_real, Y_real, _, _, Y_r_min, Y_r_max), (X_imag, Y_imag, _, _, Y_i_min, Y_i_max) in zip(test_loader_real, test_loader_imag):
            # Move inputs to device
            X_real, X_imag = X_real.to(device), X_imag.to(device)

            # 1. Flatten for memoryless prediction
            X_real_flat = X_real.view(-1, 1)
            X_imag_flat = X_imag.view(-1, 1)

            # Predict
            # ! shouldnt use .numpy() method because of criterion
            pred_real_flat = Test_Mod_Re(X_real_flat)
            pred_imag_flat = Test_Mod_Im(X_imag_flat)

            # 2. Calculate MSE Loss on the flat tensors
            loss_real = criterion(pred_real_flat, Y_real.view(-1, 1))
            loss_imag = criterion(pred_imag_flat, Y_imag.view(-1, 1))

            test_loss_real += loss_real.item()
            test_loss_imag += loss_imag.item()

            # 3. Reshape back to the original array shape (e.g. [10000, 1024])
            pred_real = pred_real_flat.view_as(X_real).cpu().numpy()
            pred_imag = pred_imag_flat.view_as(X_imag).cpu().numpy()

            # 4. Denormalize using the exact physical limits from the dictionary!
            pred_denorm_real = denormalize(pred_real, (Y_r_min, Y_r_max))
            pred_denorm_imag = denormalize(pred_imag, (Y_i_min, Y_i_max))

            # 5. Reconstruct complex signals
            orig_complex = X_real.cpu().numpy() + 1j * X_imag.cpu().numpy()
            clip_complex = Y_real.cpu().numpy() + 1j * Y_imag.cpu().numpy()
            pred_complex = pred_denorm_real + 1j * pred_denorm_imag

            all_original.append(orig_complex)
            all_clipped.append(clip_complex)
            all_predicted.append(pred_complex)

    # Print the final average test metrics
    avg_test_loss_real = test_loss_real / len(test_loader_real)
    avg_test_loss_imag = test_loss_imag / len(test_loader_imag)

    print(f'\n--- Test Set Metrics ({test_size} Unseen Files) ---')
    print(f'Average Real Module MSE Loss: {avg_test_loss_real:.6f}')
    print(f'Average Imag Module MSE Loss: {avg_test_loss_imag:.6f}')

    # 4. Concatenate the test_size batches into one massive array for evaluation
    original_complex = np.concatenate(all_original, axis=0)
    clipped_complex = np.concatenate(all_clipped, axis=0)
    predicted_complex = np.concatenate(all_predicted, axis=0)

    print(f'Testing complete! Aggregated {test_size * samples_per_L} OFDM symbols.')
# Out:
# --- Test Set Metrics (20 Unseen Files) ---
# Average Real Module MSE Loss: 0.000511
# Average Imag Module MSE Loss: 0.000241
# Testing complete! Aggregated 200000 OFDM symbols.

# %% [markdown]
# Cell 10: Plotting

# %%
# 5. Calculate PAPR and CM for CCDF
orig_papr, clip_papr, pred_papr = [], [], []
orig_cm, clip_cm, pred_cm = [], [], []

# Iterate through the arrays
for i in range(test_size * samples_per_L if not one_batch else samples_per_L):
    # orig_papr.append(calculate_papr(original_complex[i]))
    # clip_papr.append(calculate_papr(clipped_complex[i]))
    # pred_papr.append(calculate_papr(predicted_complex[i]))

    orig_cm.append(calculate_cm(original_complex[i]))
    clip_cm.append(calculate_cm(clipped_complex[i]))
    pred_cm.append(calculate_cm(predicted_complex[i]))

orig_papr, clip_papr, pred_papr = np.array(orig_papr), np.array(clip_papr), np.array(pred_papr)
orig_cm, clip_cm, pred_cm = np.array(orig_cm), np.array(clip_cm), np.array(pred_cm)

# 6. Plot the CCDF
title = f'NN{tech.upper()} Predicted OFDM\n{params}'
labels = ['Original OFDM', f'{tech.upper()}', f'NN{tech.upper()} Predicted OFDM']
papr_list = [orig_papr, clip_papr, pred_papr]
cm_list = [orig_cm, clip_cm, pred_cm]

# plot_ccdf_compare(papr_list, f'Original vs {tech.upper()} vs {title}', labels)
plot_ccdf_compare(cm_list, f'Original vs {tech.upper()} vs {title}', labels, metric="CM")

# fixme: both percentile and max are not the most efficient solutions

# todo: find a way to embed the floor part into the plotting function
# 1. Define the target y-levels (probabilities)
papr_target_y = 1e-4
cm_target_y = 1e-3

# 2. Convert CCDF y-level to a standard percentile (e.g., 1e-4 becomes 99.99)
papr_percentile = (1.0 - papr_target_y) * 100.0
cm_percentile = (1.0 - cm_target_y) * 100.0

# 3. Extract the exact x-axis values (PAPR/CM) where the line cuts the graph
# (This completely replaces the need for y_axis, np.where, and manual sorting!)
# papr_vlines = [
#     np.percentile(orig_papr, papr_percentile),
#     np.percentile(clip_papr, papr_percentile),
#     np.percentile(pred_papr, papr_percentile)
# ]

cm_vlines = [
    np.percentile(orig_cm, cm_percentile),
    np.percentile(clip_cm, cm_percentile),
    np.percentile(pred_cm, cm_percentile)
]

# cm_vlines = [
#     np.max(orig_cm),
#     np.max(clip_cm),
#     np.max(pred_cm)
# ]

# # 4. Plot!
# # papr_image_path = os.path.join(graph_dir, f"{opt}_{mod}_papr_{train_val_test_str}_{lr_str}.png")
# # plot_ccdf(pred_papr, title, metric="papr", vlines=papr_vlines, save=papr_image_path)
# plot_ccdf(pred_papr, title, metric="papr", vlines=papr_vlines)

cm_image_path = os.path.join(graph_dir, f"{opt}_{mod}_{tech}_cm_{train_val_test_str}_{lr_str}.png")
plot_ccdf(pred_cm, title, metric="cm", vlines=cm_vlines, save=cm_image_path)
