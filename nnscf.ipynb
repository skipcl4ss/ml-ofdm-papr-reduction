# %% [markdown]
# A test to see which number is more suitable for set_num_threads

# %%
# import torch
# import time
#
# def benchmark_threads(num_threads, matrix_size=4000, iterations=20):
#     # Set the number of threads for this test run
#     torch.set_num_threads(num_threads)
#
#     # Create two massive random matrices to simulate deep learning workloads
#     A = torch.randn(matrix_size, matrix_size)
#     B = torch.randn(matrix_size, matrix_size)
#
#     # Warmup round (gets the CPU caches loaded and ready)
#     _ = torch.matmul(A, B)
#
#     # Start the actual timer
#     start_time = time.time()
#
#     # Run the heavy math multiple times
#     for _ in range(iterations):
#         _ = torch.matmul(A, B)
#
#     end_time = time.time()
#
#     print(f"Total time with {num_threads} threads: {end_time - start_time:.4f} seconds")
#
# print("--- PyTorch CPU Thread Benchmark ---")
# # Test with 4 threads
# benchmark_threads(4)
#
# # Test with 8 threads
# benchmark_threads(8)

# %% [markdown]
# 8 threads is faster than 4 threads, so we will use 8 threads for the rest of the code

# %% [markdown]
# Cell 1: Imports and Device Setup

# %%
import numpy as np
from ofdm.metrics import calculate_papr, calculate_cm
from ofdm.plots import plot_ccdf, plot_ccdf_compare
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
# from torchmin import Minimizer
import os
import time
import matplotlib.pyplot as plt
from IPython.display import clear_output, display

# %%
# Explicitly tell PyTorch to utilize your 8 CPU cores for matrix math
# Check for GPU availability to drastically speed up training
# ! cuda is available only on nvidia gpu
torch.set_num_threads(8)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"PyTorch using {torch.get_num_threads()} threads on {device}")
# Out:
# PyTorch using 8 threads on cpu

# %%
samples_per_L = 10000

# Modulation scheme
mod = "16qam"
# mod = "qpsk"
print(f"Using {mod.upper()} modulation technique")

# clipping technique
# tech = "icf"
tech = "scf"
print(f"Using {tech} clipping technique")

# Hyperparameters
epochs = 100
# using 0.001 for Adam and 0.01 for LBFGS as default values
# lr = 0.001
lr = 0.01
lr_list = str(float(lr)).split(".")
lr_str = f"dot{lr_list[1]}" if lr < 1 else f"{lr_list[0]}dot{lr_list[1]}"
print(f"Hyperparameters: epochs = {epochs}, learning rate = {lr} ({lr_str} used in naming files), batch size = None (for now)")

# Optimizer
# opt = "Adam"
opt = "LBFGS"
print(f"Using {opt} optimizer")

# Data splitting
# ! make sure that the splitting is the same as in renormalization.ipynb
datasize = 100
# datasize = 120
train_size = 70
val_size = 10
test_size = datasize - train_size - val_size
if test_size:
    one_batch = None
else:
    test_size = 1
    one_batch = "00"
train_val_test_str = f"{train_size}_{val_size}_{test_size}" if val_size else f"{train_size}_{test_size}"
print(f"dataset of size {datasize} is split into {train_size} training files, and {val_size} validation and {test_size} testing batches respectively ({train_val_test_str} used in naming files)")

batch_suffix = ""
if one_batch:
    batch_suffix = f"Batch #{one_batch}"
    print(f"This one batch is of index {one_batch}")
    if train_size + val_size == datasize:
        print(batch_suffix, "was already used in training")

params = f"{opt} optimizer {tech.upper()} {mod.upper()} lr = {lr}\n({train_size} Training/{val_size} Validation/{test_size} Testing){" (" + batch_suffix + ")" if batch_suffix else ''}"
print(params)

og_pt_dir = "./pt_dir/"
pt_dir = "./pt_dir_globalnorm/"
model_dir = "./new architecture/"
graph_dir = "./new architecture/"
os.makedirs(og_pt_dir, exist_ok=True)
os.makedirs(pt_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(graph_dir, exist_ok=True)
print(og_pt_dir, "is the location of the original pt files before implementing the brand new normalization method suggested by gemini")
print(f'"{pt_dir}", "{model_dir}", and "{graph_dir}" are the 3 locations for pt files, nn model weights and graphs respectively')
# Out:
# Using 16QAM modulation technique
# Using scf clipping technique
# Hyperparameters: epochs = 100, learning rate = 0.01 (dot01 used in naming files), batch size = None (for now)
# Using LBFGS optimizer
# dataset of size 100 is split into 70 training files, and 10 validation and 20 testing batches respectively (70_10_20 used in naming files)
# LBFGS optimizer SCF 16QAM lr = 0.01
# (70 Training/10 Validation/20 Testing)
# ./pt_dir/ is the location of the original pt files before implementing the brand new normalization method suggested by gemini
# "./pt_dir_globalnorm/", "./new architecture/", and "./new architecture/" are the 3 locations for pt files, nn model weights and graphs respectively

# %%
def denormalize(pred_norm, minmax):
    raw_min, raw_max = minmax
    pred_raw = ((pred_norm + 1.0) / 2.0) * (raw_max - raw_min) + raw_min if raw_max != raw_min else pred_norm
    return pred_raw

# %% [markdown]
# Cell 2: Custom Activation Function

# %%
class TriangularActivation(nn.Module):
    """
    Implements the triangular activation function used in the paper's hidden layers.
    Mathematically equivalent to MATLAB's 'tribas': f(x) = max(1 - |x|, 0)
    """
    def forward(self, x):
        return torch.clamp(1.0 - torch.abs(x), min=0.0)

# %% [markdown]
# Cell 3: Highly Optimized Dataset Class

# %% [markdown]
# This is fast as it works with .pt directly without conversion

# %%
class FastOFDMDataset(Dataset):
    def __init__(self, pt_folder_path, part):
        self.folder_path = pt_folder_path
        self.part = part

    def __len__(self):
        return datasize # Assuming exactly 100 pre-computed .pt files, regardless of train/test split

    def __getitem__(self, idx):
        # Instantly loads the pre-normalized tensors directly into memory!
        file_path = os.path.join(self.folder_path, f"{mod}_{tech}_part_{idx:03d}_{self.part}.pt")
        # Load the dictionary
        data_pkg = torch.load(file_path, weights_only=False)

        # Return the tensors AND the scaling limits
        return (data_pkg['X_norm'], data_pkg['Y_norm'],
                data_pkg['X_min'], data_pkg['X_max'],
                data_pkg['Y_min'], data_pkg['Y_max'])

# %% [markdown]
# Cell 4: Neural Network Architecture

# %%
class NNSCFMapper(nn.Module):
    def __init__(self):
        super(NNSCFMapper, self).__init__()
        # First hidden layer: 2 neurons
        self.hidden1 = nn.Linear(1, 2)
        # Second hidden layer: 1 neuron
        self.hidden2 = nn.Linear(2, 1)
        # Output layer: Maps back to the original subcarrier points
        self.output = nn.Linear(1, 1)
        # Custom triangular activation
        self.activation = TriangularActivation()

    def forward(self, x):
        x = self.activation(self.hidden1(x))
        x = self.activation(self.hidden2(x))
        x = self.output(x) # Standard linear output
        return x

# %% [markdown]
# Cell 5: Initialization and DataLoaders

# %%
# todo: make edits so that it works if using one batch
# fixme: find alternative shuffling technique
# Configuration

# Initialize DataLoaders with asynchronous loading (num_workers) and rapid memory transfer
dataset_real = FastOFDMDataset(pt_dir, part='real')
if train_size < datasize:
    # ! note that the output of the Subset is saved in the original variable, may be important later
    train_dataset_real = Subset(dataset_real, range(train_size))  # Use the first train_size files for training
    val_dataset_real = Subset(dataset_real, range(train_size, train_size + val_size))

# ? should i change batch_size in the new architecture
train_loader_real = DataLoader(
    train_dataset_real,
    batch_size=None, # batch_size is None because the dataset returns a full batch of 10,000
    shuffle=True,
    # shuffle=False,
    # ! does not work locally on windows when changed to 2-4 for some reason
    num_workers=0,   # Adjust between 2-4 based on your CPU cores
    pin_memory=torch.cuda.is_available()
)

dataset_imag = FastOFDMDataset(pt_dir, part='imag')
if train_size < datasize:
    train_dataset_imag = Subset(dataset_imag, range(train_size))  # Use the first train_size files for training
    val_dataset_imag = Subset(dataset_imag, range(train_size, train_size + val_size))

train_loader_imag = DataLoader(
    train_dataset_imag,
    batch_size=None,
    shuffle=True,
    # shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)


val_loader_real = DataLoader(
    val_dataset_real,
    batch_size=None, # batch_size is None because the dataset returns a full batch of 10,000
    shuffle=False,
    # ! does not work locally on windows when changed to 2-4 for some reason
    num_workers=0,   # Adjust between 2-4 based on your CPU cores
    pin_memory=torch.cuda.is_available()
)
val_loader_imag = DataLoader(
    val_dataset_imag,
    batch_size=None,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

# Initialize models and send them to the GPU/device
Mod_Re_NN = NNSCFMapper().to(device)
Mod_Im_NN = NNSCFMapper().to(device)

# todo: see how can i use loss function to reduce ber
# Standard Mean Squared Error loss and optimizer
criterion = nn.MSELoss()
if opt == "Adam":
    optimizer_real = optim.Adam(Mod_Re_NN.parameters(), lr=lr)
    optimizer_imag = optim.Adam(Mod_Im_NN.parameters(), lr=lr)
elif opt == "LBFGS":
    optimizer_real = optim.LBFGS(Mod_Re_NN.parameters(), lr=lr, tolerance_change=1e-5, max_iter=5)
    optimizer_imag = optim.LBFGS(Mod_Im_NN.parameters(), lr=lr, tolerance_change=1e-5, max_iter=5)
# elif opt == "LM":
#     optimizer_real = Minimizer(Mod_Re_NN.parameters(), method='levenberg-marquardt')
#     optimizer_imag = Minimizer(Mod_Im_NN.parameters(), method='levenberg-marquardt')

# %% [markdown]
# Not using .compile() is actually better, it also avoids the hassle of cl.exe and needing to run "x64 Native Tools Command Prompt for VS".
#
# dont know if thats the case with gpu or not tho

# %% [markdown]
# Cell 6: Training Loop (Real Module)

# %%
print("--- Starting Training for the Real NN Module ---")
train_loss_history = []  # Track losses for graphing
val_loss_history = []
log_lines = []
total_time = 0
train_time = 0
val_time = 0

# ! if using .compile(), it is expected for the first epoch to take longer
for epoch in range(1, epochs + 1):
    start = time.time()
    epoch_train_loss = 0.0

    # Training
    Mod_Re_NN.train()
    for X_batch, Y_batch, _, _, _, _ in train_loader_real:
        # Transfer data to GPU if possible
        X_batch, Y_batch = X_batch.to(device, non_blocking=True), Y_batch.to(device, non_blocking=True)

        # MEMORYLESS RESHAPE: Flatten into a 1D column
        X_batch_flat = X_batch.view(-1, 1)
        Y_batch_flat = Y_batch.view(-1, 1)

        if opt == "Adam":
            optimizer_real.zero_grad(set_to_none=True)
            # Predict on the flattened column
            predictions = Mod_Re_NN(X_batch_flat)
            loss = criterion(predictions, Y_batch_flat)
            loss.backward()
            optimizer_real.step()
            epoch_train_loss += loss.item()
        # elif opt == "LBFGS" or opt == "LM:
        elif opt == "LBFGS":
            # L-BFGS and LM require a "closure" function to recalculate the loss, but for LM it is often required to return the unreduced residuals
            def closure():
                optimizer_real.zero_grad(set_to_none=True)
                predictions = Mod_Re_NN(X_batch_flat)

                # if opt == "LM":
                #     # LM mathematically requires the raw residuals (the difference before squaring)
                #     residuals = predictions - Y_batch_flat

                loss = criterion(predictions, Y_batch_flat)
                loss.backward()
                return loss
            # Pass the closure to the optimizer
            optimizer_real.step(closure)
            # To track the loss for your graphs, you have to call it once outside
            epoch_train_loss += closure().item()

    avg_train_loss = epoch_train_loss / len(train_loader_real)
    train_loss_history.append(avg_train_loss)  # Store loss for this epoch

    middle = time.time()

    # Validation
    Mod_Re_NN.eval()
    epoch_val_loss = 0.0
    with torch.no_grad():
        for X_val, Y_val, _, _, _, _ in val_loader_real:
            X_val, Y_val = X_val.to(device, non_blocking=True), Y_val.to(device, non_blocking=True)
            predictions = Mod_Re_NN(X_val.view(-1, 1))
            val_loss = criterion(predictions, Y_val.view(-1, 1))
            epoch_val_loss += val_loss.item()

    avg_val_loss = epoch_val_loss / len(val_loader_real)
    val_loss_history.append(avg_val_loss)

    end = time.time()

    train_time += middle - start
    val_time += end - middle
    total_time += end - start
    line = f'Real Module | Epoch {epoch}/{epochs} | Train Loss: {avg_train_loss:.6f} | Val Loss {avg_val_loss:.6f} | Time: {end - start:.2f} seconds'
    log_lines.append(line)

    if epoch % 5 == 0 or epoch == epochs:
        clear_output(wait=True)
        plt.figure(figsize=(10, 7))
        plt.plot(range(1, len(train_loss_history) + 1), train_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Train Loss")
        plt.plot(range(1, len(val_loss_history) + 1), val_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Validation Loss")
        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel('Loss (MSE)', fontsize=12)
        plt.legend()
        plt.title(f'Real Module Training & Validation Loss over Epochs\n{params}', fontsize=14, fontweight='bold')
        plt.xlim(0, epochs + 1)
        margin = (max(train_loss_history) - min(train_loss_history)) * 0.1 if len(train_loss_history) > 1 else 0.1
        plt.ylim(min(train_loss_history) - margin, max(train_loss_history) + margin)
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()
        print(*log_lines, sep='\n')
    else:
        print(line)


print(f'Real NN Module Training Complete in {int(total_time // 60)}:{total_time % 60:.1f} minutes! ({int(train_time // 60)}:{train_time % 60:.1f} minutes in training and {int(val_time // 60)}:{val_time % 60:.1f} minutes in validation)')

# Plot loss vs epoch
plt.figure(figsize=(10, 7))
plt.plot(range(1, epochs + 1), train_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Training Loss")
plt.plot(range(1, epochs + 1), val_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Validation Loss")
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss (MSE)', fontsize=12)
plt.legend()
plt.title(f'Real Module Training & Validation Loss over Epochs\n{params}', fontsize=14, fontweight='bold')
plt.xlim(0, epochs + 1)
margin = (max(train_loss_history) - min(train_loss_history)) * 0.1
plt.ylim(min(train_loss_history) - margin, max(train_loss_history) + margin)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(graph_dir, f"{opt}_{mod}_{tech}_real_loss_{train_val_test_str}_{lr_str}.png"), dpi=150)
plt.show()
# Out:
# Real Module | Epoch 1/100 | Train Loss: 0.013698 | Val Loss 0.000441 | Time: 148.25 seconds
# Real Module | Epoch 2/100 | Train Loss: 0.000330 | Val Loss 0.000256 | Time: 86.00 seconds
# Real Module | Epoch 3/100 | Train Loss: 0.000231 | Val Loss 0.000217 | Time: 78.06 seconds
# Real Module | Epoch 4/100 | Train Loss: 0.000212 | Val Loss 0.000212 | Time: 65.84 seconds
# Real Module | Epoch 5/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.53 seconds
# Real Module | Epoch 6/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.09 seconds
# Real Module | Epoch 7/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 58.10 seconds
# Real Module | Epoch 8/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.79 seconds
# Real Module | Epoch 9/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 59.30 seconds
# Real Module | Epoch 10/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 59.35 seconds
# Real Module | Epoch 11/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 60.17 seconds
# Real Module | Epoch 12/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 59.67 seconds
# Real Module | Epoch 13/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 62.98 seconds
# Real Module | Epoch 14/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 59.03 seconds
# Real Module | Epoch 15/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 58.37 seconds
# Real Module | Epoch 16/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 55.85 seconds
# Real Module | Epoch 17/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 55.80 seconds
# Real Module | Epoch 18/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 62.99 seconds
# Real Module | Epoch 19/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.97 seconds
# Real Module | Epoch 20/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 60.14 seconds
# Real Module | Epoch 21/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 59.16 seconds
# Real Module | Epoch 22/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 59.04 seconds
# Real Module | Epoch 23/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.00 seconds
# Real Module | Epoch 24/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 58.71 seconds
# Real Module | Epoch 25/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.60 seconds
# Real Module | Epoch 26/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 61.49 seconds
# Real Module | Epoch 27/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 58.99 seconds
# Real Module | Epoch 28/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 58.31 seconds
# Real Module | Epoch 29/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 58.63 seconds
# Real Module | Epoch 30/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.77 seconds
# Real Module | Epoch 31/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 58.20 seconds
# Real Module | Epoch 32/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.67 seconds
# Real Module | Epoch 33/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.82 seconds
# Real Module | Epoch 34/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.41 seconds
# Real Module | Epoch 35/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 58.02 seconds
# Real Module | Epoch 36/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 58.65 seconds
# Real Module | Epoch 37/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.06 seconds
# Real Module | Epoch 38/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.55 seconds
# Real Module | Epoch 39/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.84 seconds
# Real Module | Epoch 40/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.87 seconds
# Real Module | Epoch 41/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.07 seconds
# Real Module | Epoch 42/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.15 seconds
# Real Module | Epoch 43/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.91 seconds
# Real Module | Epoch 44/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.45 seconds
# Real Module | Epoch 45/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.03 seconds
# Real Module | Epoch 46/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.04 seconds
# Real Module | Epoch 47/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.10 seconds
# Real Module | Epoch 48/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.10 seconds
# Real Module | Epoch 49/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.77 seconds
# Real Module | Epoch 50/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.37 seconds
# Real Module | Epoch 51/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.34 seconds
# Real Module | Epoch 52/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.23 seconds
# Real Module | Epoch 53/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.29 seconds
# Real Module | Epoch 54/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.19 seconds
# Real Module | Epoch 55/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.52 seconds
# Real Module | Epoch 56/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.99 seconds
# Real Module | Epoch 57/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.25 seconds
# Real Module | Epoch 58/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.78 seconds
# Real Module | Epoch 59/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.36 seconds
# Real Module | Epoch 60/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.82 seconds
# Real Module | Epoch 61/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.06 seconds
# Real Module | Epoch 62/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.01 seconds
# Real Module | Epoch 63/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.99 seconds
# Real Module | Epoch 64/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.33 seconds
# Real Module | Epoch 65/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.04 seconds
# Real Module | Epoch 66/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.99 seconds
# Real Module | Epoch 67/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 64.76 seconds
# Real Module | Epoch 68/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 61.40 seconds
# Real Module | Epoch 69/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 62.73 seconds
# Real Module | Epoch 70/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 67.84 seconds
# Real Module | Epoch 71/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 76.75 seconds
# Real Module | Epoch 72/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 61.72 seconds
# Real Module | Epoch 73/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 59.17 seconds
# Real Module | Epoch 74/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 59.04 seconds
# Real Module | Epoch 75/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 58.48 seconds
# Real Module | Epoch 76/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 58.89 seconds
# Real Module | Epoch 77/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 60.42 seconds
# Real Module | Epoch 78/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 60.46 seconds
# Real Module | Epoch 79/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 60.17 seconds
# Real Module | Epoch 80/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 59.95 seconds
# Real Module | Epoch 81/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 60.01 seconds
# Real Module | Epoch 82/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 59.86 seconds
# Real Module | Epoch 83/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.89 seconds
# Real Module | Epoch 84/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.29 seconds
# Real Module | Epoch 85/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 58.10 seconds
# Real Module | Epoch 86/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.96 seconds
# Real Module | Epoch 87/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.61 seconds
# Real Module | Epoch 88/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 56.85 seconds
# Real Module | Epoch 89/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.59 seconds
# Real Module | Epoch 90/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.87 seconds
# Real Module | Epoch 91/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.55 seconds
# Real Module | Epoch 92/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.34 seconds
# Real Module | Epoch 93/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 62.15 seconds
# Real Module | Epoch 94/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 59.74 seconds
# Real Module | Epoch 95/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 59.18 seconds
# Real Module | Epoch 96/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 57.98 seconds
# Real Module | Epoch 97/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 61.74 seconds
# Real Module | Epoch 98/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 61.07 seconds
# Real Module | Epoch 99/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 62.39 seconds
# Real Module | Epoch 100/100 | Train Loss: 0.000211 | Val Loss 0.000212 | Time: 74.21 seconds
# Real NN Module Training Complete in 100:30.4 minutes! (96:42.3 minutes in training and 3:48.1 minutes in validation)

# %% [markdown]
# Cell 7: Training Loop (Imaginary Module)

# %%
print("--- Starting Training for the Imaginary NN Module ---")
train_loss_history = []  # Track losses for graphing
val_loss_history = []
log_lines = []
total_time = 0
train_time = 0
val_time = 0

for epoch in range(1, epochs + 1):
    start = time.time()

    # Training
    Mod_Im_NN.train()
    epoch_train_loss = 0.0
    for X_batch, Y_batch, _, _, _, _ in train_loader_imag:
        # Transfer data to GPU if possible
        X_batch, Y_batch = X_batch.to(device, non_blocking=True), Y_batch.to(device, non_blocking=True)

        # MEMORYLESS RESHAPE: Flatten into a 1D column
        X_batch_flat = X_batch.view(-1, 1)
        Y_batch_flat = Y_batch.view(-1, 1)

        if opt == "Adam":
            optimizer_imag.zero_grad(set_to_none=True)
            # Predict on the flattened column
            predictions = Mod_Im_NN(X_batch_flat)
            loss = criterion(predictions, Y_batch_flat)
            loss.backward()
            optimizer_imag.step()
            epoch_train_loss += loss.item()
        # elif opt == "LBFGS" or opt == "LM:
        elif opt == "LBFGS":
            # L-BFGS and LM require a "closure" function to recalculate the loss, but for LM it is often required to return the unreduced residuals
            def closure():
                optimizer_imag.zero_grad(set_to_none=True)
                predictions = Mod_Im_NN(X_batch_flat)

                # if opt == "LM":
                #     # LM mathematically requires the raw residuals (the difference before squaring)
                #     residuals = predictions - Y_batch_flat

                loss = criterion(predictions, Y_batch_flat)
                loss.backward()
                return loss
            # Pass the closure to the optimizer
            optimizer_imag.step(closure)
            # To track the loss for your graphs, you have to call it once outside
            epoch_train_loss += closure().item()

    avg_train_loss = epoch_train_loss / len(train_loader_imag)
    train_loss_history.append(avg_train_loss)  # Store loss for this epoch

    middle = time.time()

    # Validation
    Mod_Im_NN.eval()
    epoch_val_loss = 0.0
    with torch.no_grad():
        for X_val, Y_val, _, _, _, _ in val_loader_imag:
            X_val, Y_val = X_val.to(device, non_blocking=True), Y_val.to(device, non_blocking=True)
            predictions = Mod_Im_NN(X_val.view(-1, 1))
            val_loss = criterion(predictions, Y_val.view(-1, 1))
            epoch_val_loss += val_loss.item()

    avg_val_loss = epoch_val_loss / len(val_loader_imag)
    val_loss_history.append(avg_val_loss)

    end = time.time()

    train_time += middle - start
    val_time += end - middle
    total_time += end - start
    line = f'Imaginary Module | Epoch {epoch}/{epochs} | Train Loss: {avg_train_loss:.6f} | Val Loss {avg_val_loss:.6f} | Time: {end - start:.2f} seconds'
    log_lines.append(line)

    if epoch % 5 == 0 or epoch == epochs:
        clear_output(wait=True)
        plt.figure(figsize=(10, 7))
        plt.plot(range(1, len(train_loss_history) + 1), train_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Train Loss")
        plt.plot(range(1, len(val_loss_history) + 1), val_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Validation Loss")
        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel('Loss (MSE)', fontsize=12)
        plt.legend()
        plt.title(f'Imaginary Module Training & Validation Loss over Epochs\n{params}', fontsize=14, fontweight='bold')
        plt.xlim(0, epochs + 1)
        margin = (max(train_loss_history) - min(train_loss_history)) * 0.1 if len(train_loss_history) > 1 else 0.1
        plt.ylim(min(train_loss_history) - margin, max(train_loss_history) + margin)
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()
        print(*log_lines, sep='\n')
    else:
        print(line)


print(f'Imaginary NN Module Training Complete in {int(total_time // 60)}:{total_time % 60:.1f} minutes! ({int(train_time // 60)}:{train_time % 60:.1f} minutes in training and {int(val_time // 60)}:{val_time % 60:.1f} minutes in validation)')

# Plot loss vs epoch
plt.figure(figsize=(10, 7))
plt.plot(range(1, epochs + 1), train_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Training Loss")
plt.plot(range(1, epochs + 1), val_loss_history, marker='o', linestyle='-', linewidth=2, markersize=4, label="Validation Loss")
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss (MSE)', fontsize=12)
plt.legend()
plt.title(f'Imaginary Module Training & Validation Loss over Epochs\n{params}', fontsize=14, fontweight='bold')
plt.xlim(0, epochs + 1)
margin = (max(train_loss_history) - min(train_loss_history)) * 0.1
plt.ylim(min(train_loss_history) - margin, max(train_loss_history) + margin)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(graph_dir, f"{opt}_{mod}_{tech}_imag_loss_{train_val_test_str}_{lr_str}.png"), dpi=150)
plt.show()
# Out:
# Imaginary Module | Epoch 1/100 | Train Loss: 0.073270 | Val Loss 0.008234 | Time: 166.63 seconds
# Imaginary Module | Epoch 2/100 | Train Loss: 0.000925 | Val Loss 0.000473 | Time: 103.87 seconds
# Imaginary Module | Epoch 3/100 | Train Loss: 0.000404 | Val Loss 0.000361 | Time: 83.20 seconds
# Imaginary Module | Epoch 4/100 | Train Loss: 0.000341 | Val Loss 0.000325 | Time: 83.74 seconds
# Imaginary Module | Epoch 5/100 | Train Loss: 0.000310 | Val Loss 0.000284 | Time: 77.88 seconds
# Imaginary Module | Epoch 6/100 | Train Loss: 0.000263 | Val Loss 0.000246 | Time: 99.68 seconds
# Imaginary Module | Epoch 7/100 | Train Loss: 0.000239 | Val Loss 0.000239 | Time: 67.89 seconds
# Imaginary Module | Epoch 8/100 | Train Loss: 0.000236 | Val Loss 0.000233 | Time: 74.92 seconds
# Imaginary Module | Epoch 9/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 62.22 seconds
# Imaginary Module | Epoch 10/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 62.85 seconds
# Imaginary Module | Epoch 11/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 58.72 seconds
# Imaginary Module | Epoch 12/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 62.98 seconds
# Imaginary Module | Epoch 13/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 67.14 seconds
# Imaginary Module | Epoch 14/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 73.01 seconds
# Imaginary Module | Epoch 15/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 59.74 seconds
# Imaginary Module | Epoch 16/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 59.76 seconds
# Imaginary Module | Epoch 17/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 63.19 seconds
# Imaginary Module | Epoch 18/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 73.47 seconds
# Imaginary Module | Epoch 19/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 71.36 seconds
# Imaginary Module | Epoch 20/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 62.59 seconds
# Imaginary Module | Epoch 21/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 60.35 seconds
# Imaginary Module | Epoch 22/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.11 seconds
# Imaginary Module | Epoch 23/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.11 seconds
# Imaginary Module | Epoch 24/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 56.59 seconds
# Imaginary Module | Epoch 25/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 56.34 seconds
# Imaginary Module | Epoch 26/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 58.90 seconds
# Imaginary Module | Epoch 27/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 58.56 seconds
# Imaginary Module | Epoch 28/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.43 seconds
# Imaginary Module | Epoch 29/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.68 seconds
# Imaginary Module | Epoch 30/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.50 seconds
# Imaginary Module | Epoch 31/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.80 seconds
# Imaginary Module | Epoch 32/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.60 seconds
# Imaginary Module | Epoch 33/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 58.26 seconds
# Imaginary Module | Epoch 34/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.65 seconds
# Imaginary Module | Epoch 35/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.35 seconds
# Imaginary Module | Epoch 36/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.35 seconds
# Imaginary Module | Epoch 37/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.55 seconds
# Imaginary Module | Epoch 38/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.42 seconds
# Imaginary Module | Epoch 39/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 58.17 seconds
# Imaginary Module | Epoch 40/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.84 seconds
# Imaginary Module | Epoch 41/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.57 seconds
# Imaginary Module | Epoch 42/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.82 seconds
# Imaginary Module | Epoch 43/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.41 seconds
# Imaginary Module | Epoch 44/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.64 seconds
# Imaginary Module | Epoch 45/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.84 seconds
# Imaginary Module | Epoch 46/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.34 seconds
# Imaginary Module | Epoch 47/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.32 seconds
# Imaginary Module | Epoch 48/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.58 seconds
# Imaginary Module | Epoch 49/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.71 seconds
# Imaginary Module | Epoch 50/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.48 seconds
# Imaginary Module | Epoch 51/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.28 seconds
# Imaginary Module | Epoch 52/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.15 seconds
# Imaginary Module | Epoch 53/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 60.45 seconds
# Imaginary Module | Epoch 54/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 61.54 seconds
# Imaginary Module | Epoch 55/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 59.69 seconds
# Imaginary Module | Epoch 56/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.41 seconds
# Imaginary Module | Epoch 57/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 56.05 seconds
# Imaginary Module | Epoch 58/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 58.47 seconds
# Imaginary Module | Epoch 59/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 60.34 seconds
# Imaginary Module | Epoch 60/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 60.10 seconds
# Imaginary Module | Epoch 61/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 60.29 seconds
# Imaginary Module | Epoch 62/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 60.32 seconds
# Imaginary Module | Epoch 63/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 60.22 seconds
# Imaginary Module | Epoch 64/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 59.94 seconds
# Imaginary Module | Epoch 65/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 59.52 seconds
# Imaginary Module | Epoch 66/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 59.65 seconds
# Imaginary Module | Epoch 67/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 59.62 seconds
# Imaginary Module | Epoch 68/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 60.21 seconds
# Imaginary Module | Epoch 69/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 59.20 seconds
# Imaginary Module | Epoch 70/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 58.39 seconds
# Imaginary Module | Epoch 71/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.55 seconds
# Imaginary Module | Epoch 72/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.83 seconds
# Imaginary Module | Epoch 73/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.61 seconds
# Imaginary Module | Epoch 74/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.53 seconds
# Imaginary Module | Epoch 75/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.27 seconds
# Imaginary Module | Epoch 76/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 56.84 seconds
# Imaginary Module | Epoch 77/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 56.52 seconds
# Imaginary Module | Epoch 78/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 56.64 seconds
# Imaginary Module | Epoch 79/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 56.55 seconds
# Imaginary Module | Epoch 80/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 56.84 seconds
# Imaginary Module | Epoch 81/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 56.89 seconds
# Imaginary Module | Epoch 82/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.32 seconds
# Imaginary Module | Epoch 83/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 56.67 seconds
# Imaginary Module | Epoch 84/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 56.59 seconds
# Imaginary Module | Epoch 85/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 58.27 seconds
# Imaginary Module | Epoch 86/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.93 seconds
# Imaginary Module | Epoch 87/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.59 seconds
# Imaginary Module | Epoch 88/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.40 seconds
# Imaginary Module | Epoch 89/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.85 seconds
# Imaginary Module | Epoch 90/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.08 seconds
# Imaginary Module | Epoch 91/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.57 seconds
# Imaginary Module | Epoch 92/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.52 seconds
# Imaginary Module | Epoch 93/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.41 seconds
# Imaginary Module | Epoch 94/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.32 seconds
# Imaginary Module | Epoch 95/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 57.95 seconds
# Imaginary Module | Epoch 96/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 61.73 seconds
# Imaginary Module | Epoch 97/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 74.71 seconds
# Imaginary Module | Epoch 98/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 62.12 seconds
# Imaginary Module | Epoch 99/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 59.71 seconds
# Imaginary Module | Epoch 100/100 | Train Loss: 0.000233 | Val Loss 0.000233 | Time: 58.62 seconds
# Imaginary NN Module Training Complete in 103:20.4 minutes! (99:30.1 minutes in training and 3:50.3 minutes in validation)

# %% [markdown]
# Cell 8: Saving the Models

# %%
# Save the trained models
torch.save(Mod_Re_NN.state_dict(), os.path.join(model_dir, f"{opt}_{mod}_{tech}_mod_re_weights_{train_val_test_str}_{lr_str}.pth"))
torch.save(Mod_Im_NN.state_dict(), os.path.join(model_dir, f"{opt}_{mod}_{tech}_mod_im_weights_{train_val_test_str}_{lr_str}.pth"))
print("\nTraining complete and weights saved!")
# Out:
# Training complete and weights saved!

# %% [markdown]
# Since we already saved the models, we can comment out most of the previous code blocks

# %% [markdown]
# Cell 9: Testing

# %%
# 1. Load the Saved Models
Test_Mod_Re = NNSCFMapper().to(device)
Test_Mod_Im = NNSCFMapper().to(device)

Test_Mod_Re.load_state_dict(torch.load(os.path.join(model_dir, f"{opt}_{mod}_{tech}_mod_re_weights_{train_val_test_str}_{lr_str}.pth"), weights_only=True))
Test_Mod_Im.load_state_dict(torch.load(os.path.join(model_dir, f"{opt}_{mod}_{tech}_mod_im_weights_{train_val_test_str}_{lr_str}.pth"), weights_only=True))

Test_Mod_Re.eval()
Test_Mod_Im.eval()
# Out:
# NNICFMapper(
#   (hidden1): Linear(in_features=1, out_features=2, bias=True)
#   (hidden2): Linear(in_features=2, out_features=1, bias=True)
#   (output): Linear(in_features=1, out_features=1, bias=True)
#   (activation): TriangularActivation()
# )

# %%
if one_batch:
    # 2. Grab one batch of data to test (Load the dictionary packages)
    pkg_real = torch.load(os.path.join(pt_dir, f"{mod}_{tech}_part_{one_batch}_real.pt"), weights_only=False)
    pkg_imag = torch.load(os.path.join(pt_dir, f"{mod}_{tech}_part_{one_batch}_imag.pt"), weights_only=False)
    # Extract tensors
    test_X_real, test_Y_real = pkg_real['X_norm'], pkg_real['Y_norm']
    test_X_imag, test_Y_imag = pkg_imag['X_norm'], pkg_imag['Y_norm']

    # 3. Generate Predictions (Reshape, Predict, Reshape back)
    with torch.no_grad():
        # Memoryless flattening
        X_real_flat = test_X_real.view(-1, 1).to(device)
        X_imag_flat = test_X_imag.view(-1, 1).to(device)

        predicted_real = Test_Mod_Re(X_real_flat).view_as(test_X_real).cpu().numpy()
        predicted_imag = Test_Mod_Im(X_imag_flat).view_as(test_X_imag).cpu().numpy()

    # Denormalize using exact dictionary limits
    pred_denorm_real = denormalize(predicted_real, (pkg_real['X_min'], pkg_real['X_max']))
    pred_denorm_imag = denormalize(predicted_imag, (pkg_imag['X_min'], pkg_imag['X_max']))

    # 4. Reconstruct the Complex OFDM Signals
    original_complex = test_X_real.numpy() + 1j * test_X_imag.numpy()
    clipped_complex = test_Y_real.numpy() + 1j * test_Y_imag.numpy()
    predicted_complex = pred_denorm_real + 1j * pred_denorm_imag
else:
#     # 2. Setup the Test Data (Files train_size->99)
#     test_dataset_real = Subset(FastOFDMDataset(pt_dir, part='real'), range(train_size, datasize))
#     test_dataset_imag = Subset(FastOFDMDataset(pt_dir, part='imag'), range(train_size, datasize))
    # 2. Setup the Test Data (Files (train_size+val_size)->99)
    test_dataset_real = Subset(dataset_real, range(train_size + val_size, datasize))
    test_dataset_imag = Subset(dataset_imag, range(train_size + val_size, datasize))

    # We set shuffle=False to ensure real and imag batches stay perfectly aligned
    test_loader_real = DataLoader(test_dataset_real, batch_size=None, shuffle=False)
    test_loader_imag = DataLoader(test_dataset_imag, batch_size=None, shuffle=False)

    # 3. Generate Predictions for all test_size test files
    all_original, all_clipped, all_predicted = [], [], []

    test_loss_real = 0.0
    test_loss_imag = 0.0
    with torch.no_grad():
        for (X_real, Y_real, X_r_min, X_r_max, _, _), (X_imag, Y_imag, X_i_min, X_i_max, _, _) in zip(test_loader_real, test_loader_imag):
            # Move inputs to device
            X_real, X_imag = X_real.to(device), X_imag.to(device)

            # 1. Flatten for memoryless prediction
            X_real_flat = X_real.view(-1, 1)
            X_imag_flat = X_imag.view(-1, 1)

            # Predict
            # ! shouldnt use .numpy() method because of criterion
            pred_real_flat = Test_Mod_Re(X_real_flat)
            pred_imag_flat = Test_Mod_Im(X_imag_flat)

            # 2. Calculate MSE Loss on the flat tensors
            loss_real = criterion(pred_real_flat, Y_real.view(-1, 1))
            loss_imag = criterion(pred_imag_flat, Y_imag.view(-1, 1))

            test_loss_real += loss_real.item()
            test_loss_imag += loss_imag.item()

            # 3. Reshape back to the original array shape (e.g. [10000, 1024])
            pred_real = pred_real_flat.view_as(X_real).cpu().numpy()
            pred_imag = pred_imag_flat.view_as(X_imag).cpu().numpy()

            # 4. Denormalize using the exact physical limits from the dictionary!
            pred_denorm_real = denormalize(pred_real, (X_r_min, X_r_max))
            pred_denorm_imag = denormalize(pred_imag, (X_i_min, X_i_max))

            # 5. Reconstruct complex signals
            orig_complex = X_real.cpu().numpy() + 1j * X_imag.cpu().numpy()
            clip_complex = Y_real.cpu().numpy() + 1j * Y_imag.cpu().numpy()
            pred_complex = pred_denorm_real + 1j * pred_denorm_imag

            all_original.append(orig_complex)
            all_clipped.append(clip_complex)
            all_predicted.append(pred_complex)

    # Print the final average test metrics
    avg_test_loss_real = test_loss_real / len(test_loader_real)
    avg_test_loss_imag = test_loss_imag / len(test_loader_imag)

    print(f'\n--- Test Set Metrics ({test_size} Unseen Files) ---')
    print(f'Average Real Module MSE Loss: {avg_test_loss_real:.6f}')
    print(f'Average Imag Module MSE Loss: {avg_test_loss_imag:.6f}')

    # 4. Concatenate the test_size batches into one massive array for evaluation
    original_complex = np.concatenate(all_original, axis=0)
    clipped_complex = np.concatenate(all_clipped, axis=0)
    predicted_complex = np.concatenate(all_predicted, axis=0)

    print(f'Testing complete! Aggregated {test_size * samples_per_L} OFDM symbols.')
# Out:
# --- Test Set Metrics (20 Unseen Files) ---
# Average Real Module MSE Loss: 0.000212
# Average Imag Module MSE Loss: 0.000233
# Testing complete! Aggregated 200000 OFDM symbols.

# %% [markdown]
# Cell 10: Plotting

# %%
# 5. Calculate PAPR and CM for CCDF
orig_papr, clip_papr, pred_papr = [], [], []
orig_cm, clip_cm, pred_cm = [], [], []

# Iterate through the arrays
for i in range(test_size * samples_per_L if not one_batch else samples_per_L):
    # orig_papr.append(calculate_papr(original_complex[i]))
    # clip_papr.append(calculate_papr(clipped_complex[i]))
    # pred_papr.append(calculate_papr(predicted_complex[i]))

    orig_cm.append(calculate_cm(original_complex[i]))
    clip_cm.append(calculate_cm(clipped_complex[i]))
    pred_cm.append(calculate_cm(predicted_complex[i]))

orig_papr, clip_papr, pred_papr = np.array(orig_papr), np.array(clip_papr), np.array(pred_papr)
orig_cm, clip_cm, pred_cm = np.array(orig_cm), np.array(clip_cm), np.array(pred_cm)

# 6. Plot the CCDF
title = f'NN{tech.upper()} Predicted OFDM\n{params}'
labels = ['Original OFDM', f'{tech.upper()}', f'NN{tech.upper()} Predicted OFDM']
papr_list = [orig_papr, clip_papr, pred_papr]
cm_list = [orig_cm, clip_cm, pred_cm]

# plot_ccdf_compare(papr_list, f'Original vs {tech.upper()} vs {title}', labels)
plot_ccdf_compare(cm_list, f'Original vs {tech.upper()} vs {title}', labels, metric="CM")

# fixme: both percentile and max are not the most efficient solutions

# todo: find a way to embed the floor part into the plotting function
# 1. Define the target y-levels (probabilities)
papr_target_y = 1e-4
cm_target_y = 1e-3

# 2. Convert CCDF y-level to a standard percentile (e.g., 1e-4 becomes 99.99)
papr_percentile = (1.0 - papr_target_y) * 100.0
cm_percentile = (1.0 - cm_target_y) * 100.0

# 3. Extract the exact x-axis values (PAPR/CM) where the line cuts the graph
# (This completely replaces the need for y_axis, np.where, and manual sorting!)
# papr_vlines = [
#     np.percentile(orig_papr, papr_percentile),
#     np.percentile(clip_papr, papr_percentile),
#     np.percentile(pred_papr, papr_percentile)
# ]

cm_vlines = [
    np.percentile(orig_cm, cm_percentile),
    np.percentile(clip_cm, cm_percentile),
    np.percentile(pred_cm, cm_percentile)
]

# cm_vlines = [
#     np.max(orig_cm),
#     np.max(clip_cm),
#     np.max(pred_cm)
# ]

# # 4. Plot!
# # papr_image_path = os.path.join(graph_dir, f"{opt}_{mod}_papr_{train_val_test_str}_{lr_str}.png")
# # plot_ccdf(pred_papr, title, metric="papr", vlines=papr_vlines, save=papr_image_path)
# plot_ccdf(pred_papr, title, metric="papr", vlines=papr_vlines)

cm_image_path = os.path.join(graph_dir, f"{opt}_{mod}_{tech}_cm_{train_val_test_str}_{lr_str}.png")
plot_ccdf(pred_cm, title, metric="cm", vlines=cm_vlines, save=cm_image_path)
